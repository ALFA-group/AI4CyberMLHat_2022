# %%
import json
from transformers import (
    AutoTokenizer,
    AutoModelForMaskedLM,
    Trainer,
    TrainingArguments,
    DataCollatorForLanguageModeling,
)
from datasets import Dataset

# %%
with open("w_dict.json", "r") as f:
    w_dict = json.load(f)
with open("ap_dict.json", "r") as f:
    ap_dict = json.load(f)
with open("technique_dict.json", "r") as f:
    technique_dict = json.load(f)
with open("tactic_dict.json", "r") as f:
    tactic_dict = json.load(f)

# %%
f = open("cwe_mitigation_ids_temp.json")
w_mitigation = json.load(f)

f = open("capec_mitigation_temp.json")
ap_mitigation = json.load(f)

f = open("technique_mitigation_temp.json")
technique_mitigation = json.load(f)

f = open("technique_detection_temp.json")
technique_detection = json.load(f)

f = open("capec_detection_temp.json")
ap_detection = json.load(f)

f = open("cwe_detection_temp.json")
w_detection = json.load(f)

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")


def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True)


device = "cpu"

data = set()

for w in w_dict:
    data.add(w_dict[w]["name"])
for ap in ap_dict:
    data.add(ap_dict[ap]["name"])
for tech in technique_dict:
    data.add(technique_dict[tech]["name"])
for tac in tactic_dict:
    data.add(tactic_dict[tac]["name"])
for mitigation in w_mitigation:
    data.add(mitigation["metadata"]["Description"])
for detection in w_detection:
    data.add(detection["metadata"]["Description"])
for mitigation in ap_mitigation:
    data.add(mitigation["metadata"])
for detection in ap_detection:
    data.add(detection["metadata"])
for mitigation in technique_mitigation:
    data.add(mitigation["name"])
for detection in technique_detection:
    data.add(detection["name"])

dataset = {"text": list(data)}
dataset = Dataset.from_dict(dataset)
dataset = dataset.train_test_split(test_size=0.1)

tokenized_datasets = dataset.map(
    tokenize_function, batched=True, remove_columns=["text"]
)

model = AutoModelForMaskedLM.from_pretrained("bert-base-uncased")

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer)

training_args = TrainingArguments(
    "bert_base",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    num_train_epochs=50.0,
    save_total_limit=1,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    data_collator=data_collator,
)

trainer.train()
trainer.save_model()
# Out:
#   0%|          | 0/4 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /home/ubuntu/venv_BRON_ML/lib/python3.6/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 3809
#   Num Epochs = 50
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 95250
#     <div>
#
#       <progress value='95250' max='95250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [95250/95250 15:04:13, Epoch 50/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.037800</td>
#       <td>3.071460</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.818700</td>
#       <td>2.728717</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.523200</td>
#       <td>2.731335</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.429700</td>
#       <td>2.810951</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.366800</td>
#       <td>2.610152</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.237100</td>
#       <td>2.765339</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.995100</td>
#       <td>2.579362</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.004600</td>
#       <td>2.766116</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.900000</td>
#       <td>2.929121</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.747700</td>
#       <td>2.646270</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.632000</td>
#       <td>2.708073</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.631600</td>
#       <td>2.444237</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.470600</td>
#       <td>2.735118</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.492900</td>
#       <td>2.760572</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.457700</td>
#       <td>2.572687</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.354200</td>
#       <td>2.510020</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.460000</td>
#       <td>2.470235</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.377500</td>
#       <td>2.682118</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.230100</td>
#       <td>2.592304</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.289500</td>
#       <td>2.731010</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.186600</td>
#       <td>2.680697</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.034500</td>
#       <td>2.803011</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.003400</td>
#       <td>2.597025</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.030500</td>
#       <td>2.884346</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.870000</td>
#       <td>2.679439</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.761800</td>
#       <td>2.830223</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.086600</td>
#       <td>2.924690</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.826300</td>
#       <td>2.744296</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.856500</td>
#       <td>2.512988</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.754500</td>
#       <td>2.680164</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.803100</td>
#       <td>2.596526</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.690300</td>
#       <td>2.503499</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.625300</td>
#       <td>2.703051</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.654000</td>
#       <td>2.360031</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.598000</td>
#       <td>2.258506</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.662300</td>
#       <td>2.424518</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.516800</td>
#       <td>2.594737</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.528400</td>
#       <td>2.690280</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.503900</td>
#       <td>2.483672</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.475200</td>
#       <td>2.717351</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.602100</td>
#       <td>2.680578</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.463200</td>
#       <td>2.705710</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.495400</td>
#       <td>2.457725</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.441400</td>
#       <td>2.459729</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.364200</td>
#       <td>2.655340</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.343300</td>
#       <td>2.637520</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.404800</td>
#       <td>2.409842</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.382000</td>
#       <td>2.856293</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.332300</td>
#       <td>2.594057</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.398100</td>
#       <td>2.635175</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-1905
# Configuration saved in bert_base/checkpoint-1905/config.json
# Model weights saved in bert_base/checkpoint-1905/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-3810
# Configuration saved in bert_base/checkpoint-3810/config.json
# Model weights saved in bert_base/checkpoint-3810/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-1905] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-5715
# Configuration saved in bert_base/checkpoint-5715/config.json
# Model weights saved in bert_base/checkpoint-5715/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-7620
# Configuration saved in bert_base/checkpoint-7620/config.json
# Model weights saved in bert_base/checkpoint-7620/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-5715] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-9525
# Configuration saved in bert_base/checkpoint-9525/config.json
# Model weights saved in bert_base/checkpoint-9525/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-3810] due to args.save_total_limit
# Deleting older checkpoint [bert_base/checkpoint-7620] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-11430
# Configuration saved in bert_base/checkpoint-11430/config.json
# Model weights saved in bert_base/checkpoint-11430/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-13335
# Configuration saved in bert_base/checkpoint-13335/config.json
# Model weights saved in bert_base/checkpoint-13335/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-9525] due to args.save_total_limit
# Deleting older checkpoint [bert_base/checkpoint-11430] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-15240
# Configuration saved in bert_base/checkpoint-15240/config.json
# Model weights saved in bert_base/checkpoint-15240/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-17145
# Configuration saved in bert_base/checkpoint-17145/config.json
# Model weights saved in bert_base/checkpoint-17145/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-15240] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-19050
# Configuration saved in bert_base/checkpoint-19050/config.json
# Model weights saved in bert_base/checkpoint-19050/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-17145] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-20955
# Configuration saved in bert_base/checkpoint-20955/config.json
# Model weights saved in bert_base/checkpoint-20955/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-19050] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-22860
# Configuration saved in bert_base/checkpoint-22860/config.json
# Model weights saved in bert_base/checkpoint-22860/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-13335] due to args.save_total_limit
# Deleting older checkpoint [bert_base/checkpoint-20955] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-24765
# Configuration saved in bert_base/checkpoint-24765/config.json
# Model weights saved in bert_base/checkpoint-24765/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-26670
# Configuration saved in bert_base/checkpoint-26670/config.json
# Model weights saved in bert_base/checkpoint-26670/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-24765] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-28575
# Configuration saved in bert_base/checkpoint-28575/config.json
# Model weights saved in bert_base/checkpoint-28575/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-26670] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-30480
# Configuration saved in bert_base/checkpoint-30480/config.json
# Model weights saved in bert_base/checkpoint-30480/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-28575] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-32385
# Configuration saved in bert_base/checkpoint-32385/config.json
# Model weights saved in bert_base/checkpoint-32385/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-30480] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-34290
# Configuration saved in bert_base/checkpoint-34290/config.json
# Model weights saved in bert_base/checkpoint-34290/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-32385] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-36195
# Configuration saved in bert_base/checkpoint-36195/config.json
# Model weights saved in bert_base/checkpoint-36195/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-34290] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-38100
# Configuration saved in bert_base/checkpoint-38100/config.json
# Model weights saved in bert_base/checkpoint-38100/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-36195] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-40005
# Configuration saved in bert_base/checkpoint-40005/config.json
# Model weights saved in bert_base/checkpoint-40005/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-38100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-41910
# Configuration saved in bert_base/checkpoint-41910/config.json
# Model weights saved in bert_base/checkpoint-41910/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-40005] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-43815
# Configuration saved in bert_base/checkpoint-43815/config.json
# Model weights saved in bert_base/checkpoint-43815/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-41910] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-45720
# Configuration saved in bert_base/checkpoint-45720/config.json
# Model weights saved in bert_base/checkpoint-45720/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-43815] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-47625
# Configuration saved in bert_base/checkpoint-47625/config.json
# Model weights saved in bert_base/checkpoint-47625/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-45720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-49530
# Configuration saved in bert_base/checkpoint-49530/config.json
# Model weights saved in bert_base/checkpoint-49530/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-47625] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-51435
# Configuration saved in bert_base/checkpoint-51435/config.json
# Model weights saved in bert_base/checkpoint-51435/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-49530] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-53340
# Configuration saved in bert_base/checkpoint-53340/config.json
# Model weights saved in bert_base/checkpoint-53340/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-51435] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-55245
# Configuration saved in bert_base/checkpoint-55245/config.json
# Model weights saved in bert_base/checkpoint-55245/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-53340] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-57150
# Configuration saved in bert_base/checkpoint-57150/config.json
# Model weights saved in bert_base/checkpoint-57150/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-55245] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-59055
# Configuration saved in bert_base/checkpoint-59055/config.json
# Model weights saved in bert_base/checkpoint-59055/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-57150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-60960
# Configuration saved in bert_base/checkpoint-60960/config.json
# Model weights saved in bert_base/checkpoint-60960/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-59055] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-62865
# Configuration saved in bert_base/checkpoint-62865/config.json
# Model weights saved in bert_base/checkpoint-62865/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-60960] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-64770
# Configuration saved in bert_base/checkpoint-64770/config.json
# Model weights saved in bert_base/checkpoint-64770/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-22860] due to args.save_total_limit
# Deleting older checkpoint [bert_base/checkpoint-62865] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-66675
# Configuration saved in bert_base/checkpoint-66675/config.json
# Model weights saved in bert_base/checkpoint-66675/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-64770] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-68580
# Configuration saved in bert_base/checkpoint-68580/config.json
# Model weights saved in bert_base/checkpoint-68580/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-70485
# Configuration saved in bert_base/checkpoint-70485/config.json
# Model weights saved in bert_base/checkpoint-70485/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-68580] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-72390
# Configuration saved in bert_base/checkpoint-72390/config.json
# Model weights saved in bert_base/checkpoint-72390/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-70485] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-74295
# Configuration saved in bert_base/checkpoint-74295/config.json
# Model weights saved in bert_base/checkpoint-74295/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-72390] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-76200
# Configuration saved in bert_base/checkpoint-76200/config.json
# Model weights saved in bert_base/checkpoint-76200/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-74295] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-78105
# Configuration saved in bert_base/checkpoint-78105/config.json
# Model weights saved in bert_base/checkpoint-78105/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-76200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-80010
# Configuration saved in bert_base/checkpoint-80010/config.json
# Model weights saved in bert_base/checkpoint-80010/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-78105] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-81915
# Configuration saved in bert_base/checkpoint-81915/config.json
# Model weights saved in bert_base/checkpoint-81915/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-80010] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-83820
# Configuration saved in bert_base/checkpoint-83820/config.json
# Model weights saved in bert_base/checkpoint-83820/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-81915] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-85725
# Configuration saved in bert_base/checkpoint-85725/config.json
# Model weights saved in bert_base/checkpoint-85725/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-83820] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-87630
# Configuration saved in bert_base/checkpoint-87630/config.json
# Model weights saved in bert_base/checkpoint-87630/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-85725] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-89535
# Configuration saved in bert_base/checkpoint-89535/config.json
# Model weights saved in bert_base/checkpoint-89535/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-87630] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-91440
# Configuration saved in bert_base/checkpoint-91440/config.json
# Model weights saved in bert_base/checkpoint-91440/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-89535] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-93345
# Configuration saved in bert_base/checkpoint-93345/config.json
# Model weights saved in bert_base/checkpoint-93345/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-91440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 424
#   Batch size = 2
# Saving model checkpoint to bert_base/checkpoint-95250
# Configuration saved in bert_base/checkpoint-95250/config.json
# Model weights saved in bert_base/checkpoint-95250/pytorch_model.bin
# Deleting older checkpoint [bert_base/checkpoint-93345] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bert_base/checkpoint-66675 (score: 2.2585062980651855).
# Saving model checkpoint to bert_base
# Configuration saved in bert_base/config.json
# Model weights saved in bert_base/pytorch_model.bin
